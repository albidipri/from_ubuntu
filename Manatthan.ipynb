# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

from mpl_toolkits.mplot3d import Axes3D

from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
df = pd.read_excel(r'/home/alberto/Scrivania/dropbox lavoro/miniprojects/new-york-estate/Manhattan.xlsx')
df.head()
# Out:
#    Unnamed: 0  rental_id   rent  bedrooms  bathrooms  size_sqft  \
# 0           0       1545   2550       0.0          1        480
# 1           1       2472  11500       2.0          2       2000
# 2           2       2919   4500       1.0          1        916
# 3           3       2790   4795       1.0          1        975
# 4           4       3946  17500       2.0          2       4800
#
#    min_to_subway  floor  building_age_yrs  no_fee  has_roofdeck  \
# 0              9    2.0                17       1             1
# 1              4    1.0                96       0             0
# 2              2   51.0                29       0             1
# 3              3    8.0                31       0             0
# 4              3    4.0               136       0             0
#
#    has_washer_dryer  has_doorman  has_elevator  has_dishwasher  has_patio  \
# 0                 0            0             1               1          0
# 1                 0            0             0               0          0
# 2                 0            1             1               1          0
# 3                 0            1             1               1          0
# 4                 0            1             1               1          0
#
#    has_gym       neighborhood    borough
# 0        1    Upper East Side  Manhattan
# 1        0  Greenwich Village  Manhattan
# 2        0            Midtown  Manhattan
# 3        1  Greenwich Village  Manhattan
# 4        1               Soho  Manhattan

# %%
x = df[['size_sqft','building_age_yrs']]
y = df[['rent']]

x_train, x_test, y_train, y_test = train_test_split(x, y, train_size = 0.8, test_size = 0.2, random_state=6)

ols = LinearRegression()

ols.fit(x_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
# Plot the figure

fig = plt.figure(1, figsize=(6, 4))
plt.clf()

elev = 43.5
azim = -110

ax = Axes3D(fig, elev=elev, azim=azim)

ax.scatter(x_train[['size_sqft']], x_train[['building_age_yrs']], y_train, c='k', marker='+')

ax.plot_surface(np.array([[0, 0], [4500, 4500]]), np.array([[0, 140], [0, 140]]), ols.predict(np.array([[0, 0, 4500, 4500], [0, 140, 0, 140]]).T).reshape((2, 2)), alpha=.7)

ax.set_xlabel('Size (ft$^2$)')
ax.set_ylabel('Building Age (Years)')
ax.set_zlabel('Rent ($)')

ax.w_xaxis.set_ticklabels([])
ax.w_yaxis.set_ticklabels([])
ax.w_zaxis.set_ticklabels([])
# Out:
# []

# %%
x = df[['bedrooms', 'bathrooms', 'size_sqft', 'min_to_subway', 'floor', 'building_age_yrs', 'no_fee', 'has_roofdeck', 'has_washer_dryer', 'has_doorman', 'has_elevator', 'has_dishwasher', 'has_patio', 'has_gym']]

y = df[['rent']]

x_train, x_test, y_train, y_test = train_test_split(x, y, train_size = 0.8, test_size = 0.2, random_state=50)
print(x_train.shape)
print(x_test.shape)

print(y_train.shape)
print(y_test.shape)
# Out:
# (2831, 14)
# (708, 14)
# (2831, 1)
# (708, 1)

# %%
# Create the model
mlr = LinearRegression()

# Fit the model
mlr.fit(x_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
y_predict = mlr.predict(x_test)

# %%
jack_apartment = [[3, 1, 800, 16, 1, 98, 1, 0, 1, 0, 0, 1, 1, 0]]

predict = mlr.predict(jack_apartment)

print("Predicted rent: $%.0f" % predict)
# Out:
# Predicted rent: $2647

# %%
plt.scatter(y_test, y_predict, alpha=0.4)
plt.xlabel("Prices: $Y_i$")
plt.ylabel("Predicted prices: $\hat{Y}_i$")
plt.title("Actual Rent vs Predicted Rent")
# Out:
# Text(0.5, 1.0, 'Actual Rent vs Predicted Rent')

# %%
mlr.coef_
# Out:
# array([[-317.13163159, 1238.13102683,    4.89904693,  -14.65577328,
#           23.6509752 ,   -7.49746058, -138.83867542,   24.8340771 ,
#          158.92020585,  -64.74377669,   11.66244596,  -66.95748113,
#          -73.08734377,   80.99000515]])

# %%
plt.scatter(df[['size_sqft']], df[['rent']], alpha=0.4)

# %%
print("Train score:")
print(mlr.score(x_train, y_train))
print("Test score:")
print(mlr.score(x_test, y_test))
# Out:
# Train score:
# 0.7815057285124232
# Test score:
# 0.7657984018179829

# %%
residuals = y_predict - y_test

plt.scatter(y_predict, residuals, alpha=0.4)
plt.title('Residual Analysis')

plt.show()
